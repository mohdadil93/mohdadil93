# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdadil93/mohdadil93/blob/main/Assessment2B_Mohamed_Adil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("/content/college_1.csv")
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2=pd.read_csv("/content/college_2.csv")
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df=pd.concat([df1,df2])
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df3=df[df["CodeKata Score"]>15000]
df3.to_csv('Exceeded expectations.csv',index=False)
df4=df[(df["CodeKata Score"]>10000) & (df["CodeKata Score"]<15000)]
df4.to_csv('Reached_expectations.csv',index=False)
df5=df[(df["CodeKata Score"]>7000) & (df["CodeKata Score"]<10000)]
df5.to_csv('Needs_Improvement.csv',index=False)
df6=df[df["CodeKata Score"]<7000]
df6.to_csv('Unsatisfactory.csv',index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df7=df[["Previous Geekions","CodeKata Score"]].mean()
df7
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
len(df.index)
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df8=df["python"].mean()
df8
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(n=3,columns=["Rising"])
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 2         Computer Science and Engineering    2000       55.0
# 18        Computer Science and Engineering    2000       -1.0
#
#     computational_thinking
# 8                      0.0
# 2                      6.0
# 18                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(n=3,columns=["CodeKata Score"])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
fig=px.pie(values=df["CodeKata Score"],names=df["Department"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df9=df[df.Department=="Computer Science and Engineering"].nlargest(n=5,columns=["CodeKata Score"])
df9
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0          A.Dharani    82.0   20.0              24500           24500
# 1        V.JEEVITHA     82.0   20.0              21740           21740
# 2        HEMAVATHI.R   100.0  100.0              19680           19680
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering     340       20.0                     0.0
# 2  Computer Science and Engineering    2000       55.0                     6.0

# %%
df10=df[df.Department=="Electronics and Communication Engineering"].nlargest(n=5,columns=["CodeKata Score"])
df10
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3   Bodipudi Harini    -1.0   35.0              10040           10040
# 7         Gowtham R    -1.0    4.0               8650            8650
# 6     KALAIARASAN K    85.0   47.0               7750            7880
# 14        Praneetha    -1.0  100.0               7170            7730
# 16          Guhan S    -1.0   35.0               7310            7630
#
#                                    Department  Rising  python_en  \
# 3   Electronics and Communication Engineering       0        0.0
# 7   Electronics and Communication Engineering       0       60.0
# 6   Electronics and Communication Engineering     130        NaN
# 14  Electronics and Communication Engineering     560       23.0
# 16  Electronics and Communication Engineering     320       72.0
#
#     computational_thinking
# 3                     -1.0
# 7                      6.0
# 6                      NaN
# 14                    -1.0
# ...

# %%
df11=df[df.Department=="Electronics and Electrical Engineering"].nlargest(n=5,columns=["CodeKata Score"])
df11
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0   ASHOK KUMAR K   100.0   31.0              19400           19400
# 4       VIINU V P    -1.0   24.0               9150            9150
# 8        shifak N    58.0    0.0               5180            8320
# 9         Balaji     -1.0   20.0               6170            8160
# 12       JPradhap   100.0    0.0               7340            8030
#
#                                 Department  Rising  python_en  \
# 0   Electronics and Electrical Engineering       0        0.0
# 4   Electronics and Electrical Engineering       0      100.0
# 8   Electronics and Electrical Engineering    3140        0.0
# 9   Electronics and Electrical Engineering    1990      100.0
# 12  Electronics and Electrical Engineering     690        0.0
#
#     computational_thinking
# 0                      9.0
# 4                     -1.0
# 8                      0.0
# 9                      0.0
# 12                     0.0

# %%
fd=pd.concat([df9,df10,df11])
fig=px.scatter(fd,x="Name",y="CodeKata Score",color="Department",symbol="Department")#bubble chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
